# %%
import sys
import os
sys.path.append(os.path.abspath("../"))


from Preprocessing.preprocessing_pipeline_impute_fuel_types import preprocessing_pipeline

# %%
df = preprocessing_pipeline()

# %%
df[df['fuel_type'] == 'Electric'].head()
# Out:
#       brand        model  color  year  price_in_euro  power_ps  \
# 16313  audi  Audi e-tron  beige  2019          51888     408.0
# 16320  audi  Audi e-tron  beige  2019          53990     408.0
# 16322  audi  Audi e-tron  beige  2019          54870     408.0
# 16330  audi  Audi e-tron  beige  2019          61989     408.0
# 16338  audi  Audi e-tron   blue  2019          32930     408.0
#
#       transmission_type fuel_type  fuel_consumption_l_100km  mileage_in_km  \
# 16313         Automatic  Electric                       0.0        84800.0
# 16320         Automatic  Electric                       0.0        51000.0
# 16322         Automatic  Electric                       0.0        82814.0
# 16330         Automatic  Electric                       0.0        55990.0
# 16338         Automatic  Electric                       0.0        84300.0
#
#        electric_range  registration_month
# 16313           359.0                   9
# 16320           359.0                   7
# ...

# %%
df[df['fuel_type'] == 'LPG'].head()
# Out:
#      brand            model   color  year  price_in_euro  power_ps  \
# 1648  audi          Audi S8  silver  1997          21899     340.0
# 1796  audi          Audi A3  silver  2000           3600     179.0
# 1825  audi          Audi S6    blue  2001           8000     340.0
# 1826  audi          Audi S8    blue  2001          14990     360.0
# 1862  audi  Audi A6 allroad   black  2001           6657     250.0
#
#      transmission_type fuel_type  fuel_consumption_l_100km  mileage_in_km  \
# 1648            Manual       LPG                      13.9       220000.0
# 1796            Manual       LPG                       7.8       268300.0
# 1825         Automatic       LPG                      14.2       335000.0
# 1826         Automatic       LPG                      13.7       306000.0
# 1862         Automatic       LPG                      13.4       999999.0
#
#       electric_range  registration_month
# 1648             0.0                   8
# ...
